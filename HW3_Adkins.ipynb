# %% [markdown]
# <a href="https://colab.research.google.com/github/natadkins7/MIS2800/blob/main/HW3_Adkins.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Type this code exactly as shown to intall the first library needed for SQLite3 to work using SQLite Magic
# !pip install --upgrade pandas ipython-sql prettytable==3.10.1

# %%
# Install the SQL extension. Remember to type exactly as shown here.
# !pip install ipython-sql
print("ipython sql installed")
# Out:
# ...
# ipython sql installed

# %%
#this code imports sqlite3 and prints a statement stating it has been imported
import sqlite3
print("sqlite3 imported")
# Out:
# sqlite3 imported

# %%
# This creates a brand-new, empty database file named 'AdCampaigns2026.db'
conn = sqlite3.connect('AdCampaigns2026.db')
print("database created")
# Out:
# database created

# %%
# This line is required so Colab stops acting like Python and acts more like a SQL database terminal
# %sql sqlite:///AdCampaigns2026.db

# %% [markdown]
# You're getting the `UsageError: Line magic function %sql not found.` because even though you've installed the `ipython-sql` library, you haven't loaded its extensions into the IPython environment. You need to explicitly load the `sql` extension.

# %%
# Load the ipython-sql extension
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %% [markdown]
# There are bugs (mistakes) for you to find and fix in the next 10 blocks

# %%
#Block 1
# Instructions: There is a typo in the table. Hint: a word is missing.
# %%sql
CREATE TABLE Marketing_Brands (
brand_id INTEGER PRIMARY KEY,
brand_name TEXT,
brand_type TEXT,
brand_budget INTEGER
) STRICT;
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# []

# %%
#Block 2
# Instructions: Find and fix the error.
# %%sql
INSERT INTO Marketing_Brands (brand_id, brand_name, brand_type, brand_budget)
VALUES
(1, 'Doritos', 'Snacks', 7000000),
(2, 'AWS', 'Technology', 15000000),
(3, 'Pepsi', 'Beverages', 2000000),
(4, 'He_Gets_Us', 'Religious', 1000000),
(5, 'Dr_Pepper', 'Beverages', 5000000),
(6, 'IBM', 'Technology', 100000),
(7, 'Google', 'Technology', 8000000);
# Out:
#  * sqlite:///AdCampaigns2026.db
# 7 rows affected.
# []

# %%
#Block 3
# -- Instructions: Fix the code to select all the columns
# from the Marketing_Brands table
# %%sql
SELECT * FROM Marketing_Brands;
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [(1, 'Doritos', 'Snacks', 7000000),
#  (2, 'AWS', 'Technology', 15000000),
#  (3, 'Pepsi', 'Beverages', 2000000),
#  (4, 'He_Gets_Us', 'Religious', 1000000),
#  (5, 'Dr_Pepper', 'Beverages', 5000000),
#  (6, 'IBM', 'Technology', 100000),
#  (7, 'Google', 'Technology', 8000000)]

# %%
#Block 4
# -- Instructions: Fix the code to display only the brand names and
# brand types that had budget over 700000
# %%sql
SELECT brand_name, brand_type FROM Marketing_Brands WHERE brand_budget > 700000;
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [('Doritos', 'Snacks'),
#  ('AWS', 'Technology'),
#  ('Pepsi', 'Beverages'),
#  ('He_Gets_Us', 'Religious'),
#  ('Dr_Pepper', 'Beverages'),
#  ('Google', 'Technology')]

# %%
#Block 5
# %%sql
-- Instructions: Fix the code to find the brand types that are Religious
SELECT brand_name, brand_type FROM Marketing_Brands WHERE brand_type = 'Religious';
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [('He_Gets_Us', 'Religious')]

# %%
#Block 6
# -- Instructions: Fix the code to display the
# brand names that have a budget under 1000000
# %%sql
SELECT brand_name FROM Marketing_Brands WHERE brand_budget < 1000000;
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [('IBM',)]

# %%
#Block 7
# Instructins: Fix the code so that this will run SQLite3 in
# Colab without having to wrap in Python. Hint: It's Magic!
# %%sql
SELECT * FROM Marketing_Brands WHERE brand_budget > 7000000
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [(2, 'AWS', 'Technology', 15000000), (7, 'Google', 'Technology', 8000000)]

# %%
#Block 8
# %%sql
--Instructions: Find the brands where the brand type is
# Snacks or Beverages. Display only the brand names.
SELECT brand_name FROM Marketing_Brands WHERE brand_type = 'Snacks' OR brand_type = 'Beverages';
# Out:
#  * sqlite:///AdCampaigns2026.db
# (sqlite3.OperationalError) unrecognized token: "#"
# [SQL: --Instructions: Find the brands where the brand type is
# # Snacks or Beverages. Display only the brand names.
# SELECT brand_name FROM Marketing_Brands WHERE brand_type = 'Snacks' OR brand_type = 'Beverages';]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %%
#Block 9
# %%sql
-- Instructions: Sort the table by brand budget in
# DESC order. Display only the brand_name and brand_budget.
SELECT brand_name, brand_budget FROM Marketing_Brands ORDER BY brand_budget DESC;
# Out:
#  * sqlite:///AdCampaigns2026.db
# (sqlite3.OperationalError) unrecognized token: "#"
# [SQL: -- Instructions: Sort the table by brand budget in
# # DESC order. Display only the brand_name and brand_budget.
# SELECT brand_name, brand_budget FROM Marketing_Brands ORDER BY brand_budget DESC;]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %%
#Block 10
# Using SQLite3 (and all its magic) to create a
# table showing all the columns in ascending order by budget.
# %%sql
SELECT * FROM Marketing_Brands ORDER BY brand_budget ASC;
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [(6, 'IBM', 'Technology', 100000),
#  (4, 'He_Gets_Us', 'Religious', 1000000),
#  (3, 'Pepsi', 'Beverages', 2000000),
#  (5, 'Dr_Pepper', 'Beverages', 5000000),
#  (1, 'Doritos', 'Snacks', 7000000),
#  (7, 'Google', 'Technology', 8000000),
#  (2, 'AWS', 'Technology', 15000000)]

# %% [markdown]
# 1. How did you fix the error in Block #1?
#
# Answer: The error was a missing TABLE keyword. I fixed it by changing it to CREATE TABLE Marketing_Brands.
#
# 2. How did you fix the error in Block #2?
#
# Answer: The error was a missing INTO keyword and the table name. I fixed it by changing it to INSERT INTO Marketing_Brands (brand_id, ...) VALUES (...).
#
# 3. How did you fix the error in Block #3?
#
# Answer:  The error was that it didn't specify what to select. I fixed it by adding * to select all columns: SELECT * FROM Marketing_Brands;.
#
# 4. How did you fix the error in Block #4?
#
# Answer:  The error was missing the specific columns to display and the WHERE clause for the budget condition. I fixed it by changing it to SELECT brand_name, brand_type FROM Marketing_Brands WHERE brand_budget > 700000;.
#
# 5. How did you fix the error in Block #5?
#
# Answer: The error was missing the specific columns to display and the WHERE clause for the brand type. I fixed it by changing it to SELECT brand_name, brand_type FROM Marketing_Brands WHERE brand_type = 'Religious';.
#
# 6. How did you fix the error in Block #6?
#
# Answer: The error was missing the specific column to display and the WHERE clause for the budget condition. I fixed it by changing it to SELECT brand_name FROM Marketing_Brands WHERE brand_budget < 1000000;.
#
# 7. How did you fix the error in Block #7?
#
# Answer: The error was a SyntaxError because the %%sql cell magic was missing. I fixed it by adding %%sql at the beginning of the cell: %%sql SELECT * FROM Marketing_Brands WHERE brand_budget >
# 7000000.
#
# 8. How did you fix the error in Block #8?
#
# Answer:  The error was that it selected all columns instead of just brand_name and lacked the correct WHERE clause for multiple brand types. I fixed it by changing it to SELECT brand_name FROM Marketing_Brands WHERE brand_type = 'Snacks' OR brand_type = 'Beverages';.
#
# 9. How did you fix the error in Block #9?
#
# Answer:  The error was missing the specific columns to display and the ORDER BY clause. I fixed it by changing it to SELECT brand_name, brand_budget FROM Marketing_Brands ORDER BY brand_budget DESC;.
#
# 10. How did you fix the error in Block #10?
#
# Answer: he error was the missing SQL query and %%sql magic. I fixed it by adding %%sql and the full query: %%sql SELECT * FROM Marketing_Brands ORDER BY brand_budget ASC;.
